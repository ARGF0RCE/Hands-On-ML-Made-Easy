# %% [markdown]
# <a href="https://colab.research.google.com/github/ARGF0RCE/Hands-On-ML-Made-Easy/blob/main/Part_1_Chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1
# ---
# # The Machine Learning Landscape
#
# When people hear *Machine Learning*, they picture a robot: a dependable butler or a deadly Terminator, depending on who you ask. But Machine Learning is not just a futuristic fantasy; it's already here!😎.
#
# Where does Machine learning start and where does it end? What exactly does it mean for a machine to *learn* something? If I download a copy of Wikipedia, hasa my computer really learned something? Is it suddenly smarter? In this chapte we will start by clarifying what Machine Learning is and why you may want to use it.
#
# Then, before we set out to explore the Machine Learning continent, we will take a look at the map and learn about the main regeions and the most notable landmarks:
# * Supervised vs. Unsupervised Learning
# * Online vs. batch learning
# * Instance-based vs. model-based learning.
#
# Then we will look at the workflow of a typical ML project, discuss the main challenges you'll face, and cover how to evaluate and fine-tune a Machine Learning system.
#
# This chapter introduces a lot of fundamental concpets (and jargon) that every data scientist should know by heart. So grab a coffee and let's get started...

# %% [markdown]
# ## What is Machine Learing?
#
# Machine Learning is the science (and art) of programming computers so they can *learn from data*.
#
# Here is a slightly more general definition:
#   * [Machine Learning is the] field of study that gives computers the ability to learn without being explicitly programmed.
#
# And a more engineering-oriented one:
#   * A computer program is said to learn from experience *E* with respect to some task *T* and some perfomance measure *P*, if its perfomance on *T*, as measured by *P*, improves with experience *E*.
#
# ## Why Use Machine Learning?
#
# Consider how would you would write spam filter using traditional programming techniques.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Since the problem is difficult, your program will likely become a long list of rules- pretty hard to maintain.
